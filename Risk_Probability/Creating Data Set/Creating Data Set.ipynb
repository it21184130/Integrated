# %% [markdown]
# # Preparing the probability column

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\dula\appdata\local\programs\python\python312\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\dula\appdata\local\programs\python\python312\lib\site-packages (from geopy) (2.0)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\DULA\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\DULA\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\DULA\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
from geopy.distance import geodesic

# %%
# Load the dataset
df = pd.read_csv('fraudTrain.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0        2449         1/2/2019 1:06  4.613310e+12
# 1        2472         1/2/2019 1:47  3.401870e+14
# 2        2523         1/2/2019 3:05  3.401870e+14
# 3        2546         1/2/2019 3:38  4.613310e+12
# 4        2553         1/2/2019 3:55  3.401870e+14
#
#                            merchant       category     amt  first    last  \
# 0            fraud_Rutherford-Mertz    grocery_pos  281.06  Jason  Murphy
# 1  fraud_Jenkins, Hauck and Friesen  gas_transport   11.52  Misty    Hart
# 2            fraud_Goodwin-Nitzsche    grocery_pos  276.31  Misty    Hart
# 3            fraud_Erdman-Kertzmann  gas_transport    7.03  Jason  Murphy
# 4                fraud_Koepp-Parker    grocery_pos  275.73  Misty    Hart
#
#   gender                     street  ...      lat     long  city_pop  \
# 0      M  542 Steve Curve Suite 011  ...  35.9946 -81.7266       885
# 1      F  27954 Hall Mill Suite 575  ...  29.4400 -98.4590   1595797
# 2      F  27954 Hall Mill Suite 575  ...  29.4400 -98.4590   1595797
# 3      M  542 Steve Curve Suite 011  ...  35.9946 -81.7266       885
# 4      F  27954 Hall Mill Suite 575  ...  29.4400 -98.4590   1595797
#
#                         job         dob                         trans_num  \
# 0            Soil scientist   9/15/1988  e8a81877ae9a0a7f883e15cb39dc4022
# 1  Horticultural consultant  10/28/1960  bc7d41c41103877b03232f03f1f8d3f5
# 2  Horticultural consultant  10/28/1960  b98f12f4168391b2203238813df5aa8c
# 3            Soil scientist   9/15/1988  397894a5c4c02e3c61c784001f0f14e4
# 4  Horticultural consultant  10/28/1960  7863235a750d73a244c07f1fb7f0185a
#
#     unix_time  merch_lat merch_long  is_fraud
# 0  1325466397  36.430124 -81.179483         1
# 1  1325468849  29.819364 -99.142791         1
# 2  1325473523  29.273085 -98.836360         1
# 3  1325475483  35.909292 -82.091010         1
# 4  1325476547  29.786426 -98.683410         1
#
# [5 rows x 23 columns]

# %%
# Define weights for different factors

AMOUNT_WEIGHT = 0.3
CATEGORY_WEIGHT = 0.2
TIME_WEIGHT = 0.25
DISTANCE_WEIGHT = 0.25

# %% [markdown]
# ### calculate distance between customer and merchant

# %%
# Function to calculate distance between customer and merchant
def calculate_distance(row):
    customer_location = (row['lat'], row['long'])
    merchant_location = (row['merch_lat'], row['merch_long'])
    return geodesic(customer_location, merchant_location).kilometers

# %% [markdown]
# ### **Calculate time risk**

# %%
# Function to calculate time risk (higher at late night or early morning)
def calculate_time_risk(trans_time):
    hour = datetime.strptime(trans_time, '%m/%d/%Y %H:%M').hour
    if 0 <= hour < 6 or hour >= 22:
        return 1  # High risk
    elif 6 <= hour < 9 or 18 <= hour < 22:
        return 0.5  # Moderate risk
    else:
        return 0.1  # Low risk

# %% [markdown]
# ### **Calculate category risk**

# %%
# Function to calculate category risk (set high for risky categories)
def calculate_category_risk(category):
    risky_categories = ['grocery_pos', 'shopping_net', 'misc_net', 'shopping_pos']
    if category in risky_categories:
        return 1  # High risk
    else:
        return 0.2  # Low risk

# %% [markdown]
# ### **Calculate amount risk**

# %%
# Function to calculate amount risk (high for larger amounts)
def calculate_amount_risk(amount):
    if amount > 1000:
        return 1  # High risk
    elif amount > 500:
        return 0.7  # Moderate risk
    else:
        return 0.3  # Low risk

# %% [markdown]
# ### **Calculate distance risk**

# %%
# Function to calculate distance risk (capped at 1.0)
def calculate_distance_risk(row):
    distance = calculate_distance(row)
    return min(1.0, distance / 100)  # Normalize and cap at 1.0

# %% [markdown]
# ### **Fraud probability calculation function**

# %%
def calculate_fraud_probability(row):
    amount_risk = calculate_amount_risk(row['amt'])
    category_risk = calculate_category_risk(row['category'])
    time_risk = calculate_time_risk(row['trans_date_trans_time'])
    distance_risk = calculate_distance_risk(row)
    
    # Calculate weighted probability
    fraud_probability = (amount_risk * AMOUNT_WEIGHT +
                         category_risk * CATEGORY_WEIGHT +
                         time_risk * TIME_WEIGHT +
                         distance_risk * DISTANCE_WEIGHT)
    
    # Ensure the probability does not exceed 1
    return min(fraud_probability, 1)

# %%
# Apply the probability calculation to each row
df['risk_probability'] = df.apply(calculate_fraud_probability, axis=1)

# %%
# Save the modified dataset with risk probability
df.to_csv('Train_dataset_with_probability.csv', index=False)

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0        2449         1/2/2019 1:06  4.613310e+12
# 1        2472         1/2/2019 1:47  3.401870e+14
# 2        2523         1/2/2019 3:05  3.401870e+14
# 3        2546         1/2/2019 3:38  4.613310e+12
# 4        2553         1/2/2019 3:55  3.401870e+14
#
#                            merchant       category     amt  first    last  \
# 0            fraud_Rutherford-Mertz    grocery_pos  281.06  Jason  Murphy
# 1  fraud_Jenkins, Hauck and Friesen  gas_transport   11.52  Misty    Hart
# 2            fraud_Goodwin-Nitzsche    grocery_pos  276.31  Misty    Hart
# 3            fraud_Erdman-Kertzmann  gas_transport    7.03  Jason  Murphy
# 4                fraud_Koepp-Parker    grocery_pos  275.73  Misty    Hart
#
#   gender                     street  ...     long city_pop  \
# 0      M  542 Steve Curve Suite 011  ... -81.7266      885
# 1      F  27954 Hall Mill Suite 575  ... -98.4590  1595797
# 2      F  27954 Hall Mill Suite 575  ... -98.4590  1595797
# 3      M  542 Steve Curve Suite 011  ... -81.7266      885
# 4      F  27954 Hall Mill Suite 575  ... -98.4590  1595797
#
#                         job         dob                         trans_num  \
# 0            Soil scientist   9/15/1988  e8a81877ae9a0a7f883e15cb39dc4022
# 1  Horticultural consultant  10/28/1960  bc7d41c41103877b03232f03f1f8d3f5
# 2  Horticultural consultant  10/28/1960  b98f12f4168391b2203238813df5aa8c
# 3            Soil scientist   9/15/1988  397894a5c4c02e3c61c784001f0f14e4
# 4  Horticultural consultant  10/28/1960  7863235a750d73a244c07f1fb7f0185a
#
#     unix_time  merch_lat merch_long is_fraud  risk_probability
# 0  1325466397  36.430124 -81.179483        1          0.712407
# 1  1325468849  29.819364 -99.142791        1          0.576108
# 2  1325473523  29.273085 -98.836360        1          0.642621
# 3  1325475483  35.909292 -82.091010        1          0.465530
# 4  1325476547  29.786426 -98.683410        1          0.650312
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0 trans_date_trans_time        cc_num  \
# 6001     1047089        3/10/2020 3:59  3.589290e+15
# 6002     1047157        3/10/2020 4:31  3.546670e+15
# 6003     1047208        3/10/2020 4:59  3.589290e+15
# 6004     1047521        3/10/2020 8:22  3.589290e+15
# 6005     1047918       3/10/2020 12:09  3.589290e+15
#
#                            merchant     category     amt   first     last  \
# 6001             fraud_Kris-Weimann     misc_net  690.49   Paula  Estrada
# 6002  fraud_Casper, Hand and Zulauf  grocery_pos  324.74  Jordan      May
# 6003                fraud_Kiehn Inc  grocery_pos  331.33   Paula  Estrada
# 6004             fraud_Rau and Sons  grocery_pos  356.20   Paula  Estrada
# 6005        fraud_O'Connell-Ullrich         home  249.56   Paula  Estrada
#
#      gender             street  ...     long city_pop  \
# 6001      F    350 Stacy Glens  ... -97.5936      343
# 6002      M  1626 Susan Course  ... -97.6039    13602
# 6003      F    350 Stacy Glens  ... -97.5936      343
# 6004      F    350 Stacy Glens  ... -97.5936      343
# 6005      F    350 Stacy Glens  ... -97.5936      343
#
#                                         job       dob  \
# 6001  Development worker, international aid  3/5/1972
# 6002                            Optometrist  7/5/1984
# 6003  Development worker, international aid  3/5/1972
# 6004  Development worker, international aid  3/5/1972
# 6005  Development worker, international aid  3/5/1972
#
#                              trans_num   unix_time  merch_lat merch_long  \
# 6001  fb1ddd251bbec9b84c9755e856d51723  1362887989  43.254214 -98.267759
# 6002  4dca0549e43b7e265cae7fd8a7e563b4  1362889904  33.607221 -97.996506
# 6003  d18c55035998e461aa9040e254b74925  1362891561  44.228731 -98.330520
# 6004  bdaeb5e3413a408d7e6c3720a35337d5  1362903771  43.988931 -97.989985
# 6005  8f0bac74e340483b44babb0d6d07b85b  1362917373  42.868322 -98.537668
#
#      is_fraud  risk_probability
# 6001        1          0.854881
# 6002        1          0.790000
# 6003        1          0.737749
# 6004        1          0.517672
# 6005        1          0.405000
#
# [5 rows x 24 columns]

# %%
# Load the test dataset
df_test = pd.read_csv('fraudTest.csv')

# %%
df_test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0        1685       6/21/2020 22:06  3.560730e+15
# 1        1767       6/21/2020 22:32  6.564460e+15
# 2        1781       6/21/2020 22:37  6.564460e+15
# 3        1784       6/21/2020 22:38  4.005680e+15
# 4        1857       6/21/2020 23:02  3.560730e+15
#
#                               merchant        category      amt    first  \
# 0                 fraud_Hamill-D'Amore  health_fitness    24.84   Brooke
# 1    fraud_Rodriguez, Yost and Jenkins        misc_net   780.52  Douglas
# 2                     fraud_Nienow PLC   entertainment   620.33  Douglas
# 3  fraud_Heathcote, Yost and Kertzmann    shopping_net  1077.69  William
# 4               fraud_Hermann and Sons    shopping_pos   842.65   Brooke
#
#      last gender                        street  ...      lat      long  \
# 0   Smith      F     63542 Luna Brook Apt. 012  ...  31.8599 -102.7413
# 1  Willis      M    619 Jeremy Garden Apt. 681  ...  42.5545  -90.3508
# 2  Willis      M    619 Jeremy Garden Apt. 681  ...  42.5545  -90.3508
# 3   Perry      M  458 Phillips Island Apt. 768  ...  30.4590  -90.9027
# 4   Smith      F     63542 Luna Brook Apt. 012  ...  31.8599 -102.7413
#
#    city_pop                       job        dob  \
# 0        23            Cytogeneticist  9/15/1969
# 1      1306  Public relations officer  9/10/1958
# 2      1306  Public relations officer  9/10/1958
# 3     71335                 Herbalist  5/31/1994
# 4        23            Cytogeneticist  9/15/1969
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  16bf2e46c54369a8eab2214649506425  1371852399  32.575873 -102.604290
# 1  ab4b379d2c0c9c667d46508d4e126d72  1371853942  42.461127  -91.147148
# 2  47a9987ae81d99f7832a54b29a77bf4b  1371854247  42.771834  -90.158365
# 3  fe956c7e4a253c437c18918bf96f7b62  1371854335  31.204974  -90.261595
# 4  f6838c01f5d2262006e6b71d33ba7c6d  1371855736  31.315782 -102.736390
#
#    is_fraud
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# [5 rows x 23 columns]

# %%
# Apply the probability calculation to each row
df_test['risk_probability'] = df_test.apply(calculate_fraud_probability, axis=1)

# Save the modified dataset with risk probability
df_test.to_csv('Test_dataset_with_probability.csv', index=False)

# %%
df_test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0        1685       6/21/2020 22:06  3.560730e+15
# 1        1767       6/21/2020 22:32  6.564460e+15
# 2        1781       6/21/2020 22:37  6.564460e+15
# 3        1784       6/21/2020 22:38  4.005680e+15
# 4        1857       6/21/2020 23:02  3.560730e+15
#
#                               merchant        category      amt    first  \
# 0                 fraud_Hamill-D'Amore  health_fitness    24.84   Brooke
# 1    fraud_Rodriguez, Yost and Jenkins        misc_net   780.52  Douglas
# 2                     fraud_Nienow PLC   entertainment   620.33  Douglas
# 3  fraud_Heathcote, Yost and Kertzmann    shopping_net  1077.69  William
# 4               fraud_Hermann and Sons    shopping_pos   842.65   Brooke
#
#      last gender                        street  ...      long city_pop  \
# 0   Smith      F     63542 Luna Brook Apt. 012  ... -102.7413       23
# 1  Willis      M    619 Jeremy Garden Apt. 681  ...  -90.3508     1306
# 2  Willis      M    619 Jeremy Garden Apt. 681  ...  -90.3508     1306
# 3   Perry      M  458 Phillips Island Apt. 768  ...  -90.9027    71335
# 4   Smith      F     63542 Luna Brook Apt. 012  ... -102.7413       23
#
#                         job        dob                         trans_num  \
# 0            Cytogeneticist  9/15/1969  16bf2e46c54369a8eab2214649506425
# 1  Public relations officer  9/10/1958  ab4b379d2c0c9c667d46508d4e126d72
# 2  Public relations officer  9/10/1958  47a9987ae81d99f7832a54b29a77bf4b
# 3                 Herbalist  5/31/1994  fe956c7e4a253c437c18918bf96f7b62
# 4            Cytogeneticist  9/15/1969  f6838c01f5d2262006e6b71d33ba7c6d
#
#     unix_time  merch_lat  merch_long is_fraud  risk_probability
# 0  1371852399  32.575873 -102.604290        1          0.581096
# 1  1371853942  42.461127  -91.147148        1          0.825668
# 2  1371854247  42.771834  -90.158365        1          0.572102
# 3  1371854335  31.204974  -90.261595        1          1.000000
# 4  1371855736  31.315782 -102.736390        1          0.810834
#
# [5 rows x 24 columns]
